# %%
import pandas as pd
d={}
l=[]
l1=[]
fin=open("input2.txt",'r')
for line in fin:
    line=line.strip().split(":")
    if line!=['']:
        l.append(line)

for i in l:
    if(i[1]!=''):
        d[i[0]]=int(i[1])
res=d.copy()
res.pop('Number of employees')
print(l)
print(d)
print(res)
print("Goodies and Prices:")
n=d['Number of employees']
print("Number of employees:",n)
print("\nHere the goodies that are selected for distribution are:")
for i in range(n):
    name=input()
    l1.append(name)
r=dict((k,res[k])for k in l1 if k in res)
r1=sorted(r.items(),key=lambda x:x[1])
print(r1)
emp_goodies=pd.DataFrame(r1,columns=['Goodies','Price'])
print("\n",emp_goodies)
a=res[max(res,key=res.get)]
b=res[min(res,key=res.get)]
diff=a-b
print("\nAnd the difference between the chosen goodie with highest price and the lowest price is",diff)
outfile=open('output.txt','a')
outfile.write(f'Here the goodis that are selected for distribution are:')
outfile.write(f'\n{emp_goodies}')
outfile.write(f"\nAnd the difference between the chosen goodie with highest price and the lowest price is: {diff}")
outfile.close()
# Out:
# [['Number of employees', ' 6'], ['Goodies and Prices', ''], ['Fitbit Plus', ' 7980'], ['IPods', ' 22349'], ['MI Band', ' 999'], ['Cult Pass', ' 2799'], ['Macbook Pro', ' 229900'], ['Digital Camera', ' 11101'], ['Alexa', ' 9999'], ['Sandwich Toaster', ' 2195'], ['Microwave Oven', ' 9800'], ['Scale', ' 4999']]
# {'Number of employees': 6, 'Fitbit Plus': 7980, 'IPods': 22349, 'MI Band': 999, 'Cult Pass': 2799, 'Macbook Pro': 229900, 'Digital Camera': 11101, 'Alexa': 9999, 'Sandwich Toaster': 2195, 'Microwave Oven': 9800, 'Scale': 4999}
# {'Fitbit Plus': 7980, 'IPods': 22349, 'MI Band': 999, 'Cult Pass': 2799, 'Macbook Pro': 229900, 'Digital Camera': 11101, 'Alexa': 9999, 'Sandwich Toaster': 2195, 'Microwave Oven': 9800, 'Scale': 4999}
# Goodies and Prices:
# Number of employees: 6
#
# Here the goodies that are selected for distribution are:
#  Alexa
#  Fitbit Plus
#  Scale
#  Micro Oven
#  Macbook Pro
#  Cult Plus
# [('Scale', 4999), ('Fitbit Plus', 7980), ('Alexa', 9999), ('Macbook Pro', 229900)]
#
#         Goodies   Price
# 0        Scale    4999
# 1  Fitbit Plus    7980
# 2        Alexa    9999
# 3  Macbook Pro  229900
#
# And the difference between the chosen goodie with highest price and the lowest price is 228901

# %%
import pandas as pd
d={}
l=[]
l1=[]
fin=open("input2.txt",'r')
for line in fin:
    line=line.strip().split(":")
    if line!=['']:
        l.append(line)

for i in l:
    if(i[1]!=''):
        d[i[0]]=int(i[1])
res=d.copy()
res.pop('Number of employees')
print(l)
print(d)
print(res)
print("Goodies and Prices:")
n=d['Number of employees']
print("Number of employees:",n)
print("\nHere the goodies that are selected for distribution are:")
for i in range(n):
    name=input()
    l1.append(name)
r=dict((k,res[k])for k in l1 if k in res)
r1=sorted(r.items(),key=lambda x:x[1])
print(r1)
emp_goodies=pd.DataFrame(r1,columns=['Goodies','Price'])
print("\n",emp_goodies)
a=res[max(res,key=res.get)]
b=res[min(res,key=res.get)]
diff=a-b
print("\nAnd the difference between the chosen goodie with highest price and the lowest price is",diff)
outfile=open('output1.txt','a')
outfile.write(f'Here the goodis that are selected for distribution are:')
outfile.write(f'\n{emp_goodies}')
outfile.write(f"\nAnd the difference between the chosen goodie with highest price and the lowest price is: {diff}")
outfile.close()
# Out:
# [['Number of employees', ' 6'], ['Goodies and Prices', ''], ['Fitbit Plus', ' 7980'], ['IPods', ' 22349'], ['MI Band', ' 999'], ['Cult Pass', ' 2799'], ['Macbook Pro', ' 229900'], ['Digital Camera', ' 11101'], ['Alexa', ' 9999'], ['Sandwich Toaster', ' 2195'], ['Microwave Oven', ' 9800'], ['Scale', ' 4999']]
# {'Number of employees': 6, 'Fitbit Plus': 7980, 'IPods': 22349, 'MI Band': 999, 'Cult Pass': 2799, 'Macbook Pro': 229900, 'Digital Camera': 11101, 'Alexa': 9999, 'Sandwich Toaster': 2195, 'Microwave Oven': 9800, 'Scale': 4999}
# {'Fitbit Plus': 7980, 'IPods': 22349, 'MI Band': 999, 'Cult Pass': 2799, 'Macbook Pro': 229900, 'Digital Camera': 11101, 'Alexa': 9999, 'Sandwich Toaster': 2195, 'Microwave Oven': 9800, 'Scale': 4999}
# Goodies and Prices:
# Number of employees: 6
#
# Here the goodies that are selected for distribution are:
#  Alexa
#  Sandwich Toaster
#  Microwave Oven
#  Macbook Pro
#  Digital Camera
#  IPods
# [('Sandwich Toaster', 2195), ('Microwave Oven', 9800), ('Alexa', 9999), ('Digital Camera', 11101), ('IPods', 22349), ('Macbook Pro', 229900)]
#
#              Goodies   Price
# 0  Sandwich Toaster    2195
# 1    Microwave Oven    9800
# 2             Alexa    9999
# 3    Digital Camera   11101
# 4             IPods   22349
# 5       Macbook Pro  229900
#
# And the difference between the chosen goodie with highest price and the lowest price is 228901

# %%
import pandas as pd
d={}
l=[]
l1=[]
fin=open("input3.txt",'r')
for line in fin:
    line=line.strip().split(":")
    if line!=['']:
        l.append(line)

for i in l:
    if(i[1]!=''):
        d[i[0]]=int(i[1])
res=d.copy()
res.pop('Number of employees')
print(l)
print(d)
print(res)
print("Goodies and Prices:")
n=d['Number of employees']
print("Number of employees:",n)
print("\nHere the goodies that are selected for distribution are:")
for i in range(n):
    name=input()
    l1.append(name)
r=dict((k,res[k])for k in l1 if k in res)
r1=sorted(r.items(),key=lambda x:x[1])
print(r1)
emp_goodies=pd.DataFrame(r1,columns=['Goodies','Price'])
print("\n",emp_goodies)
a=res[max(res,key=res.get)]
b=res[min(res,key=res.get)]
diff=a-b
print("\nAnd the difference between the chosen goodie with highest price and the lowest price is",diff)
outfile=open('output2.txt','a')
outfile.write(f'Here the goodis that are selected for distribution are:')
outfile.write(f'\n{emp_goodies}')
outfile.write(f"\nAnd the difference between the chosen goodie with highest price and the lowest price is: {diff}")
outfile.close()
# Out:
# [['Number of employees', ' 2'], ['Goodies and Prices', ''], ['Fitbit Plus', ' 7980'], ['IPods', ' 22349'], ['MI Band', ' 999'], ['Cult Pass', ' 2799'], ['Macbook Pro', ' 229900'], ['Digital Camera', ' 11101'], ['Alexa', ' 9999'], ['Sandwich Toaster', ' 2195'], ['Microwave Oven', ' 9800'], ['Scale', ' 4999']]
# {'Number of employees': 2, 'Fitbit Plus': 7980, 'IPods': 22349, 'MI Band': 999, 'Cult Pass': 2799, 'Macbook Pro': 229900, 'Digital Camera': 11101, 'Alexa': 9999, 'Sandwich Toaster': 2195, 'Microwave Oven': 9800, 'Scale': 4999}
# {'Fitbit Plus': 7980, 'IPods': 22349, 'MI Band': 999, 'Cult Pass': 2799, 'Macbook Pro': 229900, 'Digital Camera': 11101, 'Alexa': 9999, 'Sandwich Toaster': 2195, 'Microwave Oven': 9800, 'Scale': 4999}
# Goodies and Prices:
# Number of employees: 2
#
# Here the goodies that are selected for distribution are:
#  Alexa
#  MicroWave Oven
# [('Alexa', 9999)]
#
#    Goodies  Price
# 0   Alexa   9999
#
# And the difference between the chosen goodie with highest price and the lowest price is 228901
